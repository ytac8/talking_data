# %%
import pandas as pd
import pickle

# %%
with open('../data/pickle/train.csv.pkl', mode='rb') as f:
    train_df = pickle.load(f)

# %%
train_df.head()
# Out:
#        ip  app  device  os  channel           click_time attributed_time  \
# 0   83230    3       1  13      379  2017-11-06 14:32:21             NaN
# 1   17357    3       1  19      379  2017-11-06 14:33:34             NaN
# 2   35810    3       1  13      379  2017-11-06 14:34:12             NaN
# 3   45745   14       1  13      478  2017-11-06 14:34:52             NaN
# 4  161007    3       1  13      379  2017-11-06 14:35:08             NaN
#
#    is_attributed
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
click_time = train_df.click_time.value_counts()

# %%
click_time
# Out:
# 2017-11-07 14:00:11    1502
# 2017-11-08 14:00:16    1497
# 2017-11-07 05:00:18    1494
# 2017-11-08 03:00:07    1491
# 2017-11-07 11:00:21    1474
# 2017-11-08 14:00:23    1471
# 2017-11-09 12:00:11    1471
# 2017-11-07 05:00:15    1463
# 2017-11-07 09:00:10    1450
# 2017-11-08 14:00:09    1447
# 2017-11-08 14:00:18    1437
# 2017-11-07 14:00:12    1436
# 2017-11-08 13:00:21    1436
# 2017-11-09 12:00:14    1432
# 2017-11-08 14:00:10    1430
# 2017-11-08 14:00:13    1425
# 2017-11-08 15:00:19    1423
# 2017-11-08 14:00:15    1420
# 2017-11-08 15:00:12    1419
# 2017-11-09 11:00:19    1419
# 2017-11-08 09:00:12    1419
# 2017-11-09 11:00:13    1418
# 2017-11-09 13:00:17    1417
# 2017-11-08 03:00:18    1417
# 2017-11-07 05:00:16    1414
# 2017-11-08 03:00:09    1413
# 2017-11-08 03:00:17    1412
# 2017-11-08 03:00:08    1412
# 2017-11-07 05:00:17    1410
# 2017-11-08 13:00:14    1410
#                        ...
# 2017-11-06 15:43:49       1
# 2017-11-06 15:48:53       1
# ...

# %%
click_time.describe()
# Out:
# count    259620.000000
# mean        712.209730
# std         312.266801
# min           1.000000
# 25%         492.000000
# 50%         835.000000
# 75%         932.000000
# max        1502.000000
# Name: click_time, dtype: float64

# %%
isAttr = train_df.where(train_df.is_attributed==1)

# %%
isNotAttr = train_df.where(train_df.is_attributed==0)

# %%
attr_click = isAttr.click_time.value_counts()

# %%
not_attr_click = isNotAttr.click_time.value_counts()

# %%
attr_click.describe()
# Out:
# count    191457.000000
# mean          2.386155
# std           1.417428
# min           1.000000
# 25%           1.000000
# 50%           2.000000
# 75%           3.000000
# max          13.000000
# Name: click_time, dtype: float64

# %%
not_attr_click.describe()
# Out:
# count    259620.000000
# mean        710.450058
# std         311.458696
# min           1.000000
# 25%         491.000000
# 50%         832.000000
# 75%         930.000000
# max        1496.000000
# Name: click_time, dtype: float64

# %%
train_df.ip.value_counts()
# Out:
# 5348      1238734
# 5314      1171448
# 73516      770451
# 73487      763854
# 53454      498186
# 114276     427453
# 26995      401495
# 95766      378693
# 17149      310996
# 105475     302192
# 100275     276799
# 43793      261970
# 105560     260049
# 86767      257649
# 111025     247187
# 137052     217614
# 201182     212448
# 5178       211556
# 49602      200053
# 5147       197994
# 48282      188092
# 48212      185885
# 48240      182754
# 48170      180609
# 123994     176285
# 209663     173423
# 93587      171417
# 84896      170166
# 45745      169149
# 119369     159276
#            ...
# 287517          1
# 322237          1
# 191100          1
# 322238          1
# 275703          1
# 358930          1
# 275702          1
# 252062          1
# 144444          1
# 219639          1
# 322200          1
# 219638          1
# 144579          1
# 219598          1
# 191066          1
# 275458          1
# 358932          1
# 228052          1
# 239835          1
# ...

# %%
train_df.ip.value_counts().describe()
# Out:
# count    2.773960e+05
# mean     6.665701e+02
# std      5.446831e+03
# min      1.000000e+00
# 25%      3.000000e+00
# 50%      1.300000e+01
# 75%      1.490000e+02
# max      1.238734e+06
# Name: ip, dtype: float64

# %%
user_5348 = train_df[train_df['ip'] == 5348]

# %%
user_5348[user_5348['is_attributed'] == 1]
# Out:
#              ip  app  device  os  channel           click_time  \
# 333355     5348   19       0  38      347  2017-11-06 16:06:22
# 470922     5348   20       1  26      259  2017-11-06 16:09:20
# 664836     5348   19     322  24      213  2017-11-06 16:13:48
# 934988     5348  107       1  19      171  2017-11-06 16:20:23
# 1816213    5348    3       1  37      280  2017-11-06 16:44:17
# 2105810    5348  167       1  19      213  2017-11-06 16:53:16
# 2811466    5348  115       1  13      203  2017-11-06 17:19:20
# 3026573    5348   29       1  12      343  2017-11-06 17:29:18
# 3903869    5348  136       0  38      268  2017-11-06 18:23:27
# 5541070    5348  121       1  19      203  2017-11-06 21:41:39
# 5623878    5348   19       0  50      347  2017-11-06 21:50:35
# 6015902    5348   79       1  13      213  2017-11-06 22:19:49
# 7188278    5348   15       1  18      245  2017-11-06 23:07:45
# 7236133    5348    3       1  41      480  2017-11-06 23:09:14
# ...

# %%
with open('../data/pickle/test.csv.pkl', mode='rb') as f:
    test_df = pickle.load(f)

# %%
test_df.ip.value_counts()
# Out:
# 5348      182522
# 5314      162935
# 73516      69089
# 73487      68866
# 53454      61503
# 114276     52649
# 95766      38348
# 26995      38306
# 17149      30102
# 43793      30045
# 112302     29870
# 100275     26590
# 5178       25420
# 105475     24570
# 111025     23555
# 125222     23498
# 5147       23390
# 119531     23350
# 44595      23136
# 84896      21440
# 93587      21416
# 90850      20458
# 45745      19592
# 119369     18055
# 53964      17724
# 119349     17421
# 119289     17398
# 53715      17354
# 49602      16756
# 79857      15515
#            ...
# 90077          1
# 24574          1
# 73686          1
# 73687          1
# 57292          1
# 73716          1
# 83788          1
# 40907          1
# 8155           1
# 106474         1
# 57287          1
# 67395          1
# 122852         1
# 8161           1
# 34673          1
# 122834         1
# 57328          1
# 8174           1
# 57334          1
# 106461         1
# 24548          1
# ...
